# %% [markdown]
# # [7장 1강] - 예외 처리
# ---
# ## 실습 목표
# - 예외 처리로 숫자가 아닌 값 입력 시 프로그램의 비정상 종료를 방지할 수 있다.
# - 리스트 범위 예외를 처리하고 성공·실패와 관계없이 마무리 코드를 실행할 수 있다.
# - 의도적 예외(raise)로 기획 의도에 맞지 않는 데이터 입력 시 흐름을 제어할 수 있다.

# %% [markdown]
# ### 필수 1 : 정수 변환 예외 처리하기
# ---
# #### 문제 1-1 :  태어난 연도 입력 및 나이 계산 프로그램

# %%
try:
    year = int(input("태어난 연도를 입력하세요:"))
    age = 2026 - year
    print("나이:",age)

except ValueError:
    print("숫자만 입력할 수 있습니다.")
# Out:
# 숫자만 입력할 수 있습니다.

# %% [markdown]
# ### 필수 2 : 메뉴 선택 및 다중 예외 처리하기
# ---
# #### 문제 2-1 :  맛집 메뉴 조회 프로그램

# %%
menu = ["김밥", "라면", "떡볶이"]

try:
    index = int(input("조회할 인덱스 번호를 입력하세요: "))

except ValueError(index):
    print("숫자만 입력할 수 있습니다.")

except IndexError(menu):
    print("존재하지 않는 위치의 데이터")

# %% [markdown]
# ### 심화 1 : raise 키워드를 활용한 데이터 유효성 검증
# ---
# #### 문제 3-1 : 상품 주문 수량 검증 프로그램

# %%
def set_order(count):
    if count <= 0:
        raise ValueError("주문 수량은 1개 이상이어야 합니다.")

    print(f"주문 수량이 {count}개로 설정되었습니다.")


try:
    set_order(-3)

except ValueError as e:
    print(f"시스템 경고 {e}")
# Out:
# 시스템 경고 주문 수량은 1개 이상이어야 합니다.
