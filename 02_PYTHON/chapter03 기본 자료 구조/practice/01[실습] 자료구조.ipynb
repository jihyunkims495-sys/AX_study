# %% [markdown]
# # [3장 1강] - 시퀀스 자료구조
# ## 실습 목표
# - 리스트와 튜플의 고유한 특성을 비교하고 생성할 수 있다.
# - 인덱싱과 슬라이싱 기법을 사용하여 원하는 데이터를 추출할 수 있다.
# - 공통 연산자와 언패킹 문법을 사용하여 데이터를 결합하고 분리할 수 있다.

# %% [markdown]
# ### 필수 1 : 실습 제목
#
# #### 문제 1-1 :  과일 바구니 수정과 색상 추출

# %%
fruit = ['apple', 'banana', 'cherry']
fruit[1] =  'blueberry'
print(fruit)

color = ('red','green','blue')
print(color[-1])
# Out:
# ['apple', 'blueberry', 'cherry']
# blue

# %% [markdown]
# ### 필수 2 : 시퀀스 연산 및 포함 여부 확인
#
# #### 문제 2-1 :  회원 권한 확인 및 관리자 그룹 병합

# %%
group1 = [1,2]
group2 = [3,4]

print(group1 + group2)
# Out:
# [1, 2, 3, 4]

# %%
user_roles = ['admin','editor','member']
print('admin' in user_roles)
# Out:
# True

# %% [markdown]
# ### 심화 1 : 슬라이싱과 구조적 언패킹 활용
#
# #### 문제 3-1 : 데이터 구간 추출 및 나머지 데이터 분리

# %%
numbers = [0,1,2,3,4,5]
print(numbers[2:4])
# Out:
# [2, 3]

# %%
numbers2 = [10, 20, 30, 40]
first, *others = numbers2 #언패킹 사용법
print(first)
print(others)
# Out:
# 10
# [20, 30, 40]
