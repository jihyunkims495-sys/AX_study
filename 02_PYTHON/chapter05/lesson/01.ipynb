# %% [markdown]
# # 5장 1강 : 함수 정의와 매개변수
# ## 학습 목표
# - 코드 재사용 관점에서 함수의 필요성을 설명하고 독립된 기능을 정의할 수 있다.
# - 위치 인수, 기본값 인수, 가변 인수를 구분하여 함수 매개변수를 설계할 수 있다.

# %% [markdown]
# ![파이썬 함수 기초](../images/function_basic.png)
# 함수의 구조 : 입력 -> 처리 -> 구조

# %% [markdown]
# ## 1. 함수의 기본정의와 작동 방식
# ---
# 구조도
# # 함수의 처리 구조
# def 함수이름(매개변수,...)  #매개변수는 함수가 일을 할 때 사용할 값을 받아 두는 변수
#     처리 부분
#
#     return #함수의 처리 결과를 반환
#
# # 함수를 호출하는 방법
# 함수 이름(...) -> 엔터
#
# # 함수의 목적
# 코드의 재활용 목적
# - 함수는 이미 준비된 '레시피' 같아요.

# %%
def calc(x) :
    y = (x * 2) + 1
    return y

# %% [markdown]
# ### 2. 매개변수(parameter)와 인수(argument)
# ---
# - 매개변수 : 함수 호출 시, 입력 부분에서 값을 담아주는 변수
# - 인수 : 호출시 사용된 값

# %% [markdown]
# ### 3. 위치 인수(positional argument) 와 키워드 인수(keyword arguments)
# ---
