# %% [markdown]
# # [1장 2강] - 프로젝트 가상환경 활성화와 기본 실행 방식

# %% [markdown]
# ## 실습 목표
#
# - 프로젝트 가상환경을 활성화하여 내부 인터프리터의 구동 상태를 검증할 수 있다.
# - 파이썬의 전통적인 두 가지 실행 방식(REPL, 스크립트)의 특징과 차이점을 설명할 수 있다.

# %% [markdown]
# ### 필수 1 : 가상환경 활성화 및 REPL 실습
# #### 문제 1-1 :  프로젝트 가상환경 활성화와 대화형 셀 구동

# %%
(02-python) C:\Users\jihyu\Documents\AX_study\02_PYTHON>python
Python 3.13.14 (main, Aug  5 2026, 16:10:10) [MSC v.1944 64 bit (AMD64)] on win32
Type "help", "copyright", "credits" or "license" for more information.
>>> 10*5
50
>>> 1+1
2
>>> exist()
Traceback (most recent call last):
  File "<python-input-2>", line 1, in <module>
    exist()
    ^^^^^
NameError: name 'exist' is not defined. Did you mean: 'exit'?
>>> exist()
Traceback (most recent call last):
  File "<python-input-3>", line 1, in <module>
    exist()
    ^^^^^
NameError: name 'exist' is not defined. Did you mean: 'exit'?
>>> exit()

(02-python) C:\Users\jihyu\Documents\AX_study\02_PYTHON>deactivate
C:\Users\jihyu\Documents\AX_study\02_PYTHON>

# %% [markdown]
# ### 심화 1 : 터미널 단축키 제어와 다중 명령 스크립트 구현
# #### 문제 3-1 : 단축키로 터미널 창을 토글하고 calc.py 스크립트 일괄 실행하기

# %%
PS C:\Users\jihyu\Documents\AX_study> (Set-ExecutionPolicy -Scope Process -ExecutionPolicy RemoteSigned) ; (& c:\Users\jihyu\Documents\AX_study\02_PYTHON\.venv\Scripts\Activate.ps1)
(02-python) PS C:\Users\jihyu\Documents\AX_study> python calc.py 
C:\Users\jihyu\AppData\Roaming\uv\python\cpython-3.13-windows-x86_64-none\python.exe: can't open file 'C:\\Users\\jihyu\\Documents\\AX_study\\calc.py': [Errno 2] No such file or directory
(02-python) PS C:\Users\jihyu\Documents\AX_study> cd 02_PYTHON
(02-python) PS C:\Users\jihyu\Documents\AX_study\02_PYTHON> python calc.py
반갑습니다
50
(02-python) PS C:\Users\jihyu\Documents\AX_study\02_PYTHON>
