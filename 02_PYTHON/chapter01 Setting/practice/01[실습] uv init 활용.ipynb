# %% [markdown]
# # [1장 1강] uv init을 활용한 모던 프로젝트 시작
# ## 실습 목표
#
# - 파이썬 프로그램의 기본 출력 기능을 이해하고 가상환경에서 실행되는 메시지를 출력할 수 있다.
# - 파이썬 진입점 함수의 기본 구조를 이해하고 샘플 코드를 작성할 수 있다.

# %% [markdown]
# ###  필수 1 : 파이썬 기본 출력과 프로젝트 환영 인사
# #### 문제 1-1 :  환영 메시지 출력하기

# %%
print("Hello from first project!")
# Out:
# Hello from first project!

# %% [markdown]
# ### 필수 2 : pyproject.toml 핵심 구성 요소의 이해
# #### 문제 2-1 :  pyproject.toml 핵심 항목의 의미 출력하기

# %%
print("02-python")
print(">=3.9")
# Out:
# 02-python
# >=3.9

# %% [markdown]
# ### 심화 1 : 파이썬 프로그램 진입점 함수 구현
# #### 문제 3-1 : main 함수 구조 완성하기

# %%
def main():
    print("Hello from first-project!")


if __name__ == "__main__":
    main()
# Out:
# Hello from first-project!
