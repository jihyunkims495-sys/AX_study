# %% [markdown]
# # [1장 3강] - VS Code와 주피터 노트북 커널 연결
# ## 실습 목표
# - VS Code에서 주피터 노트북 파일을 생성하고 프로젝트 가상환경 커널을 올바르게 연결할 수 있다.
# - 단축키를 활용하여 코드 셀과 마크다운 셀을 생성하고 속성을 전환할 수 있다.
# - 주피터 노트북의 실행 번호 메커니즘을 이해하고 비순차적 실행으로 인한 오류 발생 시 초기화할 수 있다.

# %% [markdown]
# #### 문제 1-1 :  가상환경 구축 및 노트북 커널 연결

# %% [markdown]
# ### 필수 2 : 코드 셀과 마크다운 셀의 역할 분담 및 단축키 활용
# #### 문제 2-1 :  셀 속성 변경 및 텍스트 출력

# %% [markdown]
# # VS Code와 주피터 노트북 커널 연결

# %%
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# ### 심화 1 : 실행 번호 메커니즘 및 비순차 실행 오류 대응
# #### 문제 3-1 : 실행 번호 분석 및 인터프리터 세션 초기화

# %%
a = input("인사를 입력하세요: ")
if "안녕" in "안녕하세요" :
    print(f"{a}는 한국식 인사입니다")
else :
    print(f"{a}는 한국식 인사가 아닙니다.")
# Out:
# hello는 한국식 인사입니다

# %%
print("hello!")
print("안녕하세요!")
# Out:
# hello!
# 안녕하세요!
