# %% [markdown]
# # [6장 2강] - uv를 활용한 의존성 관리
# ## 실습 목표
# ---
# - uv 명령어로 파이썬 새 프로젝트를 생성할 수 있다.
# - uv add 명령어로 프로젝트에 외부 패키지를 추가할 수 있다.
# - pyproject.toml의 dependencies 항목에서 설치된 패키지를 확인할 수 있다.
# - uv sync 명령어로 가상환경을 빠르게 복원할 수 있다.

# %% [markdown]
# ### 필수 1 : uv를 이용한 새로운 파이썬 프로젝트 생성과 패키지 추가
# #### 문제 1-1 :  기초 프로젝트 생성과 데이터 분석 도구 설치

# %% [markdown]
# ### 필수 2 : pyproject.toml 파일 확인을 통한 의존성 검증
# #### 문제 2-1 :  명세 파일의 자동 동기화 상태 파악하기

# %% [markdown]
# ### 심화 1 : 가상환경 삭제 후 uv sync 복원
# ##### 문제 3-1 : .venv 폴더 제거 후 가상환경 일괄 복원
