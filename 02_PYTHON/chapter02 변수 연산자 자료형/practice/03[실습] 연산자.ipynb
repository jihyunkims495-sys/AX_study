# %% [markdown]
# # [2장 3강] - 연산자
# ## 실습 목표
# - 산술 연산자와 복합 대입 연산자를 사용하여 데이터를 가공하고 계산할 수 있다.
# - 비교 연산자를 활용하여 값의 크고 작음과 문자열의 사전 순서를 판별할 수 있다.
# - 논리 연산자의 특징과 단락 회로 평가를 이해하고 복합 조건식을 구성할 수 있다.

# %% [markdown]
# ### 필수 1 : 산술 연산자와 복합 대입 연산자의 활용
# #### 문제 1-1 :  복합 대입 연산자를 이용한 변수 값 갱신

# %%
count = int(10)
count *= 5
print(count)
# Out:
# 50

# %% [markdown]
# ### 필수 2 : 비교 연산자를 통한 문자열 데이터 식별
# #### 문제 2-1 :  알파벳 사전 순서 대소 비교

# %%
fruit1 = 'apple'
fruit2 = 'banana'
print(fruit1 < fruit2)
# Out:
# True

# %% [markdown]
# ### 심화 1 : 논리 연산자와 단락 회로 평가
# #### 문제 3-1 : 단락 회로 평가를 통한 에러 방지 조건식 구성

# %%
result = False and 500%0
print(result)
# Out:
# False
