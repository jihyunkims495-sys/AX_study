# %% [markdown]
# # [2장 2강] - 기본 자료형과 형변환
# ## 실습 목표
# - 파이썬의 네 가지 기본 자료형을 분류하고 올바르게 식별할 수 있다.
# - 명시적 형변환 함수를 적용하여 데이터 타입을 자유롭게 변환할 수 있다.
# - 정수와 실수의 연산 과정에서 발생하는 묵시적 형변환의 원리를 이해할 수 있다.
# - 데이터 검증 함수를 사용하여 변환 에러를 예방하고 안전하게 형변환할 수 있다.

# %% [markdown]
# ### 필수 1 : 기본 자료형 정의 및 문자열 결합하기
# #### 문제 1-1 :  변수 선언과 명시적 형변환을 통한 문장 완성

# %%
#변수를 선언하고 문자열 저장하기
my_name = "jihyunkim"
my_age = 39
message = f" 내 나이는 {my_age}살 입니다."
print(message)
# Out:
#  내 나이는 39살 입니다.

# %% [markdown]
# ### 필수 2 : 자동 형변환의 원리와 정수형 변환
# #### 문제 2-1 :  정수와 실수의 사칙연산 및 버림 처리

# %%
a = 10
b = 3.14

result = a + b
print(result)
# Out:
# 13.14

# %%
a = 10
b = 3.14
a = int(a)
b = int(b)
result = a + b
print(result)
# Out:
# 13

# %% [markdown]
# ### 심화 1 : 안전한 형변환을 위한 데이터 사전 검증
# #### 문제 3-1 : 검증 함수를 활용한 ValueError 에러 예방

# %%
user_input = "
age = int(user_input)

if user_input.isdigit() :
    print("정수 변환 성공!")
else : 
    print("숫자만 입력해 주세요!")
# Out:
# 정수 변환 성공!

# %%
user_input = "20"
age = int(user_input)

if user_input.isdigit() :
    print("정수 변환 성공!")
else : 
    print("숫자만 입력해 주세요!")
# Out:
# 정수 변환 성공!
