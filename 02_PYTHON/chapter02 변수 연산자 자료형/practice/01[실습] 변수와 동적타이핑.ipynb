# %% [markdown]
# # [2장 1강] - 변수와 동적 타이핑
# ## 실습 목표
# - 수의 선언 원리를 이해하고 올바른 명명 규칙에 맞추어 변수를 생성할 수 있다.
# - 동적 타이핑의 특성을 설명하고 변수의 자료형 변화를 실시간으로 확인할 수 있다.
# - 변수 재할당에 따른 메모리 주소의 변화를 내장 함수로 추적할 수 있다.

# %% [markdown]
# ### 필수 1 : 올바른 변수 명명 규칙과 스네이크 케이스 적용
# #### 문제 1-1 :  규칙에 맞는 사용자 및 상품 변수 생성

# %%
#변수/스네이크 케이스에 맞춘 사용자 이름과 나이
user_age = 30

#변수/상품 가격 변수 
product_price = 10000

#연산
print(user_age + product_price)
# Out:
# 10030

# %% [markdown]
# ### 필수 2 : 동적 타이핑의 유연성과 실시간 자료형 확인
# #### 문제 2-1 :  동일 변수의 자료형 변환 및 확인

# %%
# 변수 선언
x = 10
print(type(x))
x = "Hello"
print(type(x))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ### 심화 1 : 변수 재할당과 고유 메모리 주소 추적
# #### 문제 3-1 : id() 함수를 활용한 참조 주소 이동 확인

# %%
#변수 선언하기
age = 20
print(id(age))
# Out:
# 140718283363848

# %%
#변수의 값 수정 후, 메모리 주소 확인
age = 25
print(id(age))
# Out:
# 140718283364008

# %%
#변수의 값 수정 후, 동일한 메모리 주소 확인하기
age = 20
print(id(age))
# Out:
# 140718283363848
